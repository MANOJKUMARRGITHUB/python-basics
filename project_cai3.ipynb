# %% [markdown]
# <a href="https://colab.research.google.com/github/MANOJKUMARRGITHUB/python-basics/blob/branch1/project_cai3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# creating comparision on Local Outlier Factor on Breast Cancer Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor

# %% [markdown]
# loading breast cancer dataset

# %%
breast_cancer = load_breast_cancer()
X = breast_cancer.data
y = breast_cancer.target

# %% [markdown]
# use isolation forest

# %%
clf_iso = IsolationForest(contamination=0.1, random_state=42)
y_pred_iso = clf_iso.fit_predict(X)

# %% [markdown]
# use local outlier factor

# %%
clf_lof = LocalOutlierFactor(contamination=0.1)
y_pred_lof = clf_lof.fit_predict(X)

# %% [markdown]
# plot the graph using isolation forest and breast cancer dataset

# %%
plt.scatter(X[:, 0], X[:, 1], c=np.where(y_pred_iso == -1, 'red', 'blue'), label='Isolation Forest')
plt.title("Outlier Detection using Isolation Forest on Breast Cancer Dataset")
plt.xlabel("Mean Radius")
plt.ylabel("Mean Texture")
plt.legend()
plt.show()

# %% [markdown]
# ploat a graph using Local Outlier Factor on Breast Cancer Dataset

# %%
plt.scatter(X[:, 0], X[:, 1], c=np.where(y_pred_lof == -1, 'red', 'blue'), label='Local Outlier Factor')
plt.title("Outlier Detection using Local Outlier Factor on Breast Cancer Dataset")
plt.xlabel("Mean Radius")
plt.ylabel("Mean Texture")
plt.legend()
plt.show()
